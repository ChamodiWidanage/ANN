# %% [markdown]
# # Artificial Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Importing the dataset

# %%
dataset = pd.read_excel('IDataset1.xlsx')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Charge_type        546 non-null    object
#  1   Charge_size        546 non-null    float64
#  2   Standoff_distance  546 non-null    float64
#  3   Impulse            546 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 17.2+ KB

# %%
# convert categorical variable into dummy variables
dataset = pd.get_dummies(dataset, columns=['Charge_type'])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 546 entries, 0 to 545
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Charge_size        546 non-null    float64
#  1   Standoff_distance  546 non-null    float64
#  2   Impulse            546 non-null    float64
#  3   Charge_type_CompB  546 non-null    uint8
#  4   Charge_type_TNT    546 non-null    uint8
# dtypes: float64(3), uint8(2)
# memory usage: 14.0 KB

# %%
dataset.head()
# Out:
#    Charge_size  Standoff_distance    Impulse  Charge_type_CompB  \
# 0          0.5                1.5  58.168617                  0
# 1          0.5                2.5  38.798874                  0
# 2          0.5                3.5  28.473915                  0
# 3          0.5                4.5  22.343452                  0
# 4          0.5                5.5  18.326342                  0
#
#    Charge_type_TNT
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1

# %%
y = dataset['Impulse']
X = dataset.drop('Impulse', axis=1)
print(X.shape, y.shape)
# Out:
# (546, 4) (546,)

# %%
# convert to numpy array
X = np.array(X)
y = np.array(y)

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Hyperparameter tuning - batch size, epoch, optimizer, learning rate

# %%
# Function to create model, required for KerasClassifier
def create_model(optimizer):
 # create model
 model = Sequential()
 model.add(Dense(units=200, input_shape=(X_train.shape[1],), activation='relu'))
 model.add(Dense(units=100, activation='relu'))
 model.add(Dense(units=50, activation='relu'))
 model.add(Dense(units=1, activation='linear'))
 # Compile model
 model.compile(optimizer = optimizer, loss = 'mean_squared_error', metrics = ['mae'])
 return model

# %%
# create model
model = KerasRegressor(model=create_model, verbose=0)

# define the grid search parameters
batch_size = [40, 50, 60, 70]
epochs = [200, 400, 450, 500]
optimizer = ['RMSprop', 'Adagrad', 'Adam', 'Adamax', 'Nadam']
learn_rate = [0.01, 0.1, 0.5, 1]

# gridsearch
param_grid = dict(batch_size=batch_size, epochs=epochs, model__optimizer=optimizer, optimizer__learning_rate=learn_rate)
grid = GridSearchCV(estimator=model, param_grid=param_grid,  n_jobs=-1, cv=3, scoring = 'r2')
grid_result = grid.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.988876 using {'batch_size': 40, 'epochs': 500, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.5}
# 0.941533 (0.024625) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.01}
# 0.962186 (0.005901) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.1}
# 0.944344 (0.019658) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.5}
# 0.947126 (0.013860) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 1}
# 0.584889 (0.069947) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.01}
# 0.639902 (0.084100) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.1}
# 0.595179 (0.100687) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.5}
# 0.611384 (0.087644) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 1}
# 0.955961 (0.010920) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.01}
# 0.962395 (0.005773) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.1}
# 0.961161 (0.008303) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.5}
# 0.958540 (0.003717) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 1}
# 0.946511 (0.003390) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.01}
# 0.945236 (0.003342) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.1}
# 0.945738 (0.004026) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.5}
# 0.947279 (0.005072) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 1}
# 0.965946 (0.004715) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.01}
# 0.956914 (0.014319) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.1}
# 0.963450 (0.007395) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.5}
# 0.947480 (0.008860) with: {'batch_size': 40, 'epochs': 200, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 1}
# 0.964608 (0.009163) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.01}
# 0.945789 (0.030729) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.1}
# 0.984414 (0.001914) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.5}
# 0.967918 (0.009902) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 1}
# 0.747217 (0.059507) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.01}
# 0.741223 (0.064741) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.1}
# 0.733339 (0.034686) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.5}
# 0.745083 (0.067036) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 1}
# 0.965231 (0.015190) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.01}
# 0.966843 (0.007889) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.1}
# 0.973669 (0.004117) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.5}
# 0.979370 (0.002184) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 1}
# 0.965440 (0.005195) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.01}
# 0.963434 (0.005757) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.1}
# 0.962627 (0.007498) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.5}
# 0.961510 (0.006424) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 1}
# 0.988284 (0.003313) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.01}
# 0.978088 (0.004051) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.1}
# 0.973166 (0.009641) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.5}
# 0.975333 (0.008537) with: {'batch_size': 40, 'epochs': 400, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 1}
# 0.974292 (0.015702) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.01}
# 0.975889 (0.000871) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.1}
# 0.976017 (0.020131) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.5}
# 0.974559 (0.008477) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 1}
# 0.756689 (0.055641) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.01}
# 0.763524 (0.050660) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.1}
# 0.744751 (0.064480) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 0.5}
# 0.754483 (0.061174) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adagrad', 'optimizer__learning_rate': 1}
# 0.976245 (0.001782) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.01}
# 0.975743 (0.001488) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.1}
# 0.967522 (0.009213) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 0.5}
# 0.962729 (0.015188) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adam', 'optimizer__learning_rate': 1}
# 0.963277 (0.007391) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.01}
# 0.964069 (0.008038) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.1}
# 0.964396 (0.006567) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.5}
# 0.965845 (0.007753) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 1}
# 0.935963 (0.046271) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.01}
# 0.976556 (0.006452) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.1}
# 0.979875 (0.002857) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.5}
# 0.979544 (0.004286) with: {'batch_size': 40, 'epochs': 450, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 1}
# 0.984220 (0.001480) with: {'batch_size': 40, 'epochs': 500, 'model__optimizer': 'RMSprop', 'optimizer__learning_rate': 0.01}
# 0
with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.1}
# 0.959803 (0.004423) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 0.5}
# 0.956284 (0.006280) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Adamax', 'optimizer__learning_rate': 1}
# 0.947666 (0.035618) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.01}
# 0.967562 (0.006736) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.1}
# 0.951622 (0.028712) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 0.5}
# 0.973089 (0.002587) with: {'batch_size': 70, 'epochs': 500, 'model__optimizer': 'Nadam', 'optimizer__learning_rate': 1}

# %% [markdown]
# ### Hyperparameter tuning - batch size, epoch, learning rate

# %%
# Function to create model, required for KerasClassifier
def create_model():
 # create model
 model = Sequential()
 model.add(Dense(units=200, input_shape=(X_train.shape[1],), activation='relu'))
 model.add(Dense(units=100, activation='relu'))
 model.add(Dense(units=50, activation='relu'))
 model.add(Dense(units=1, activation='linear'))
 return model

# %%
# create model
model = KerasRegressor(model=create_model, verbose=0, optimizer = 'Nadam', loss = 'mean_squared_error', metrics = ['mae'])

# define the grid search parameters
batch_size = [50, 60, 80, 100]
epochs = [50, 100, 200]
learn_rate = [0.001, 0.01, 0.1]
#momentum = [0.8, 0.9]

# gridsearch
param_grid = dict(batch_size=batch_size, epochs=epochs, optimizer__learning_rate=learn_rate)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.997277 using {'batch_size': 60, 'epochs': 100, 'optimizer__learning_rate': 0.01}
# 0.976974 (0.017614) with: {'batch_size': 50, 'epochs': 50, 'optimizer__learning_rate': 0.01}
# 0.934511 (0.048929) with: {'batch_size': 50, 'epochs': 50, 'optimizer__learning_rate': 0.1}
# 0.289896 (0.414893) with: {'batch_size': 50, 'epochs': 50, 'optimizer__learning_rate': 0.2}
# 0.996621 (0.002431) with: {'batch_size': 50, 'epochs': 100, 'optimizer__learning_rate': 0.01}
# 0.880614 (0.097619) with: {'batch_size': 50, 'epochs': 100, 'optimizer__learning_rate': 0.1}
# 0.299880 (0.426459) with: {'batch_size': 50, 'epochs': 100, 'optimizer__learning_rate': 0.2}
# 0.992978 (0.004278) with: {'batch_size': 60, 'epochs': 50, 'optimizer__learning_rate': 0.01}
# 0.970004 (0.009733) with: {'batch_size': 60, 'epochs': 50, 'optimizer__learning_rate': 0.1}
# 0.298315 (0.438947) with: {'batch_size': 60, 'epochs': 50, 'optimizer__learning_rate': 0.2}
# 0.997277 (0.001802) with: {'batch_size': 60, 'epochs': 100, 'optimizer__learning_rate': 0.01}
# 0.936912 (0.033862) with: {'batch_size': 60, 'epochs': 100, 'optimizer__learning_rate': 0.1}
# 0.303367 (0.446741) with: {'batch_size': 60, 'epochs': 100, 'optimizer__learning_rate': 0.2}
# 0.972010 (0.019859) with: {'batch_size': 80, 'epochs': 50, 'optimizer__learning_rate': 0.01}
# 0.882566 (0.084669) with: {'batch_size': 80, 'epochs': 50, 'optimizer__learning_rate': 0.1}
# 0.375773 (0.338420) with: {'batch_size': 80, 'epochs': 50, 'optimizer__learning_rate': 0.2}
# 0.980654 (0.021292) with: {'batch_size': 80, 'epochs': 100, 'optimizer__learning_rate': 0.01}
# 0.948337 (0.040130) with: {'batch_size': 80, 'epochs': 100, 'optimizer__learning_rate': 0.1}
# -0.005370 (0.000900) with: {'batch_size': 80, 'epochs': 100, 'optimizer__learning_rate': 0.2}
# 0.962241 (0.020736) with: {'batch_size': 100, 'epochs': 50, 'optimizer__learning_rate': 0.01}
# 0.897146 (0.040488) with: {'batch_size': 100, 'epochs': 50, 'optimizer__learning_rate': 0.1}
# 0.303355 (0.433063) with: {'batch_size': 100, 'epochs': 50, 'optimizer__learning_rate': 0.2}
# 0.993725 (0.005130) with: {'batch_size': 100, 'epochs': 100, 'optimizer__learning_rate': 0.01}
# 0.911065 (0.001954) with: {'batch_size': 100, 'epochs': 100, 'optimizer__learning_rate': 0.1}
# -0.004303 (0.002623) with: {'batch_size': 100, 'epochs': 100, 'optimizer__learning_rate': 0.2}

# %% [markdown]
# ### Hyperparameter tuning - layers, neurons, activation function

# %%
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor as KR
import math
def FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes):
    layers = []
    
    nodes_increment = (last_layer_nodes - first_layer_nodes)/ (n_layers-1)
    nodes = first_layer_nodes
    for i in range(1, n_layers+1):
        layers.append(math.ceil(nodes))
        nodes = nodes + nodes_increment
    
    return layers

# %%
from tensorflow.keras.optimizers import RMSprop
def create_model(n_layers, first_layer_nodes, last_layer_nodes, activation_func):
    model = Sequential()
    n_nodes = FindLayerNodesLinear(n_layers, first_layer_nodes, last_layer_nodes)
    for i in range(1, n_layers):
        if i==1:
            model.add(Dense(units = first_layer_nodes,  input_shape=(X_train.shape[1],), activation=activation_func))
        else:
            model.add(Dense(n_nodes[i-1], activation=activation_func))
            
    #Finally, the output layer should have a single node in binary classification
    model.add(Dense(1, activation='linear'))
    opt = RMSprop(learning_rate=0.1)
    model.compile(optimizer = opt, loss = 'mean_squared_error', metrics = ['mae'])
    return model

##Wrap model into scikit-learn
model = KR(build_fn=create_model, verbose=0, epochs = 400, batch_size = 50)
# Out:
# C:\Users\Chathura Gamage\AppData\Local\Temp\ipykernel_10148\3417958943.py:18: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KR(build_fn=create_model, verbose=0, epochs = 400, batch_size = 50)

# %%
activation_funcs = ['relu', 'softplus', 'leaky_relu'] 
param_grid = dict(n_layers=[2,3], first_layer_nodes = [200,300], last_layer_nodes = [50],  activation_func = activation_funcs)
grid = GridSearchCV(estimator = model, param_grid = param_grid,  n_jobs=-1, cv=3, scoring = 'r2')
grid_result = grid.fit(X_train, y_train)

# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 676
# Best: 0.986263 using {'activation_func': 'softplus', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.980573 (0.010610) with: {'activation_func': 'relu', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.917243 (0.035116) with: {'activation_func': 'relu', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 3}
# 0.953663 (0.022865) with: {'activation_func': 'relu', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.916777 (0.034610) with: {'activation_func': 'relu', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 3}
# 0.986263 (0.002684) with: {'activation_func': 'softplus', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.958869 (0.009682) with: {'activation_func': 'softplus', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 3}
# 0.910386 (0.087254) with: {'activation_func': 'softplus', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.909530 (0.017361) with: {'activation_func': 'softplus', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 3}
# 0.931396 (0.010506) with: {'activation_func': 'leaky_relu', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 2}
# -0.865704 (1.302479) with: {'activation_func': 'leaky_relu', 'first_layer_nodes': 200, 'last_layer_nodes': 50, 'n_layers': 3}
# 0.752579 (0.266199) with: {'activation_func': 'leaky_relu', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 2}
# 0.458009 (0.332423) with: {'activation_func': 'leaky_relu', 'first_layer_nodes': 300, 'last_layer_nodes': 50, 'n_layers': 3}
